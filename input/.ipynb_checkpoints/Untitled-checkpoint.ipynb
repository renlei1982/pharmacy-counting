# %%
import pandas as pd

data = pd.read_csv('de_cc_data.txt', sep=",", header=None, names=['id', 'prescriber_last_name', 'prescriber_first_name', 'drug_name', 'drug_cost'])
data.describe()
# Out:
# C:\Users\lei\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (0,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                 id prescriber_last_name prescriber_first_name  \
# count     24525860             24525411              24525652
# unique      866572               214240                 63608
# top     1124047717                SMITH                  JOHN
# freq           559               135451                530457
#
#                         drug_name   drug_cost
# count                    24525860  24525860.0
# unique                       2750   2453361.0
# top     HYDROCODONE-ACETAMINOPHEN        48.0
# freq                       306651      2944.0

# %%
data.count()
# Out:
# id                       24525860
# prescriber_last_name     24525411
# prescriber_first_name    24525652
# drug_name                24525860
# drug_cost                24525860
# dtype: int64

# %%
data.head()
# Out:
#            id  prescriber_last_name  prescriber_first_name   drug_name  \
# 0          id  prescriber_last_name  prescriber_first_name   drug_name
# 1  1952310666             A'BODJEDI                 ENENGE  ALPRAZOLAM
# 2  1952310666             A'BODJEDI                 ENENGE  AMANTADINE
# 3  1952310666             A'BODJEDI                 ENENGE      AMBIEN
# 4  1952310666             A'BODJEDI                 ENENGE   AMBIEN CR
#
#    drug_cost
# 0  drug_cost
# 1    1964.49
# 2    1129.94
# 3    4792.29
# 4    4792.29

# %%
data.head(50)
# Out:
#             id  prescriber_last_name  prescriber_first_name  \
# 0           id  prescriber_last_name  prescriber_first_name
# 1   1952310666             A'BODJEDI                 ENENGE
# 2   1952310666             A'BODJEDI                 ENENGE
# 3   1952310666             A'BODJEDI                 ENENGE
# 4   1952310666             A'BODJEDI                 ENENGE
# 5   1952310666             A'BODJEDI                 ENENGE
# 6   1952310666             A'BODJEDI                 ENENGE
# 7   1952310666             A'BODJEDI                 ENENGE
# 8   1952310666             A'BODJEDI                 ENENGE
# 9   1952310666             A'BODJEDI                 ENENGE
# 10  1952310666             A'BODJEDI                 ENENGE
# 11  1952310666             A'BODJEDI                 ENENGE
# 12  1952310666             A'BODJEDI                 ENENGE
# 13  1952310666             A'BODJEDI                 ENENGE
# 14  1952310666             A'BODJEDI                 ENENGE
# ...

# %%
data.tail(50)
# Out:
#                   id prescriber_last_name prescriber_first_name  \
# 24525810  1609070531           ZYZNIEWSKI                 WENDY
# 24525811  1609070531           ZYZNIEWSKI                 WENDY
# 24525812  1609070531           ZYZNIEWSKI                 WENDY
# 24525813  1609070531           ZYZNIEWSKI                 WENDY
# 24525814  1609070531           ZYZNIEWSKI                 WENDY
# 24525815  1609070531           ZYZNIEWSKI                 WENDY
# 24525816  1609070531           ZYZNIEWSKI                 WENDY
# 24525817  1609070531           ZYZNIEWSKI                 WENDY
# 24525818  1609070531           ZYZNIEWSKI                 WENDY
# 24525819  1609070531           ZYZNIEWSKI                 WENDY
# 24525820  1609070531           ZYZNIEWSKI                 WENDY
# 24525821  1609070531           ZYZNIEWSKI                 WENDY
# 24525822  1609070531           ZYZNIEWSKI                 WENDY
# 24525823  1609070531           ZYZNIEWSKI                 WENDY
# ...

# %%
data.id
# Out:
# 0                   id
# 1           1952310666
# 2           1952310666
# 3           1952310666
# 4           1952310666
# 5           1952310666
# 6           1952310666
# 7           1952310666
# 8           1952310666
# 9           1952310666
# 10          1952310666
# 11          1952310666
# 12          1952310666
# 13          1952310666
# 14          1952310666
# 15          1952310666
# 16          1952310666
# 17          1952310666
# 18          1952310666
# 19          1952310666
# 20          1952310666
# 21          1952310666
# 22          1952310666
# 23          1952310666
# 24          1952310666
# 25          1952310666
# 26          1952310666
# 27          1952310666
# 28          1952310666
# 29          1952310666
#                ...
# 24525830    1124277249
# 24525831    1124277249
# 24525832    1124277249
# 24525833    1124277249
# 24525834    1124277249
# 24525835    1124277249
# 24525836    1124277249
# 24525837    1124277249
# 24525838    1124277249
# ...

# %%
data['id'].count()
# Out:
# 24525860

# %%
data.groupby('id').count()
# Out:
#             prescriber_last_name  prescriber_first_name  drug_name  drug_cost
# id
# 1003000126                    21                     21         21         21
# 1003000142                    20                     20         20         20
# 1003000167                     2                      2          2          2
# 1003000282                     1                      1          1          1
# 1003000407                    35                     35         35         35
# 1003000480                     1                      1          1          1
# 1003000522                   107                    107        107        107
# 1003000530                   127                    127        127        127
# 1003000597                     4                      4          4          4
# 1003000720                     4                      4          4          4
# 1003000753                     2                      2          2          2
# ...
